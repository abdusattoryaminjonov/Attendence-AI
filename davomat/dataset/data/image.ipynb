# %%
import numpy as np
import pandas as pd

# %%
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
from PIL import Image
image = Image.open('burger.jpg')
print(image.format)
print(image.mode)
print(image.size)
# Out:
# PNG
# RGBA
# (160, 160)

# %%
import matplotlib.pyplot as plt
import numpy as np

img_arr = np.asarray(image)
print(img_arr.dtype)
print(img_arr.shape)
plt.imshow(img_arr)
# Out:
# uint8
# (160, 160, 4)

# %%
def plot_kde(channel, color):
    """ Plots a kernel density estimate for the given data.
        
        `channel` must be a 2d array
        `color` must be a color string, e.g. 'r', 'g', or 'b'
    """
    data = channel.flatten()
    return pd.Series(data).plot.density(c=color)

channels = ['r','g','b']

def plot_rgb(image_data):
    # use enumerate to loop over colors and indexes
    for ix, color in enumerate(channels):
        print(ix)
        plt.imshow(image_data[:,:,ix])
        plt.show()

# %%
image_array = np.array(image)
plt.imshow(image_array[:,:,2])
# plt.show()
plt.imshow(image_array[:,:,0])
plt.show()
# Out:
# <Axes: ylabel='Density'>

# %%
image.save('burgerr.png', format='PNG')

# %%
hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
ver_flip = image.transpose(Image.FLIP_TOP_BOTTOM)

hoz_flip.save('burger_LEFT_RIGHT.png', format ='PNG')
ver_flip.save('burger_TOP_BOTTOM.png',format='PNG')



plt.subplot(3,1,1)
plt.imshow(image)
plt.subplot(3,1,2)
plt.imshow(hoz_flip)
plt.subplot(3,1,3)
plt.imshow(ver_flip)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 hoz_flip.save('burger_LEFT_RIGHT.png', format ='PNG')
#       5 ver_flip.save('burger_TOP_BOTTOM.png',format='PNG')
# ----> 6 plt.imshow(image[:,:,0], cmap=plt.cm.Reds_r)
#       7 plt.show()
#      10 plt.subplot(3,1,1)
#
# TypeError: 'PngImageFile' object is not subscriptable
