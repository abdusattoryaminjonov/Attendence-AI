# %%
import os
from PIL import Image
from matplotlib import pyplot as plt

# %%
from imutils import paths
import cv2

# %%
imagePaths = list(paths.list_images(r"C:\Users\asus\OneDrive\Desktop\pbl4\davomat\dataset\origin_images"))

# %%
imagePaths
# Out:
# ['C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_1.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_10.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_11.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_15.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_16.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_20.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_21.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_26.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_30.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_31.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_35.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_36.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_40.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_41.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_45.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_46.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_5.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_50.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_51.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_55.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_56.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_6.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_60.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_61.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_65.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_66.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_70.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_71.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_75.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_76.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_80.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Abdusattor\\face_81.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_1.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_10.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_11.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_15.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_16.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_20.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_21.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_25.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_26.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_30.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_31.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_35.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_36.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_40.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_41.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_45.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_46.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_5.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_50.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_51.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_55.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_56.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_6.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_60.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_61.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_65.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_66.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_70.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_71.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_75.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_76.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_80.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\admin\\face_81.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_1.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_10.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_11.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_15.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_16.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_20.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_21.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_25.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_26.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_30.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_31.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_35.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_36.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_40.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_41.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_45.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_46.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_5.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_50.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_51.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_55.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_56.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_6.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_60.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_61.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_65.jpg',
#  'C:\\Users\\asus\\OneDrive\\Desktop\\pbl4\\davomat\\dataset\\origin_images\\Alex\\face_66.jpg']

# %%
import pandas as pd
import os

# %%
image_path = "C:/Users/asus/OneDrive/Desktop/pbl4/davomat/dataset/origin_images/"
rice_label = ['Abdusattor', 'Brad Pitt']

# %%
img_list = []
label_list = []
for label in rice_label:
    for img_file in os.listdir(image_path+label):
        img_list.append(image_path+label+img_file)
        label_list.append(label)
df = pd.DataFrame({'img':img_list, 'label':label_list})

# %%
df.head()
# Out:
#                                                   img       label
# 0   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 1   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 2   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 3   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 4   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 5   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 6   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 7   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 8   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 9   C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 10  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 11  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 12  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 13  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 14  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 15  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 16  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 17  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 18  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 19  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 20  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 21  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 22  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 23  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 24  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 25  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 26  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 27  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 28  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 29  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 30  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 31  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...  Abdusattor
# 32  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...   Brad Pitt
# 33  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...   Brad Pitt
# 34  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...   Brad Pitt
# 35  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...   Brad Pitt
# 36  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...   Brad Pitt
# 37  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...   Brad Pitt
# 38  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...   Brad Pitt
# 39  C:/Users/asus/OneDrive/Desktop/pbl4/davomat/da...   Brad Pitt

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
import matplotlib.pyplot as plt
from tensorflow.keras.layers import BatchNormalization
from keras_preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir="../dataset/origin_images/"
generator = ImageDataGenerator()
train_ds = generator.flow_from_directory(train_dir,target_size=(160, 160),batch_size=32)
classes = list(train_ds.class_indices.keys())
# Out:
# Found 84 images belonging to 3 classes.

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(160,160,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(len(classes),activation='softmax'))
# model.save("my_model.keras")
# Out:
# c:\Users\asus\OneDrive\Desktop\pbl4\.venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = 'adam',
    metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 158, 158, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 79, 79, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 79, 79, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 77, 77, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 38, 38, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 38, 38, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 36, 36, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 18, 18, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 96)     │        55,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 8, 96)       │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 32)       │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 3, 3, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 3, 3, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 3, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 288)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 177,923 (695.01 KB)
#  Trainable params: 177,347 (692.76 KB)
#  Non-trainable params: 576 (2.25 KB)

# %%
history = model.fit(train_ds,epochs= 10, batch_size=32)
# Out:
# Epoch 1/10
# c:\Users\asus\OneDrive\Desktop\pbl4\.venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 313ms/step - accuracy: 0.4559 - loss: 1.2051
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - accuracy: 0.9881 - loss: 0.1079
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - accuracy: 0.9881 - loss: 0.0397
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.9814 - loss: 0.0337
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 7.3440e-04

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.xlabel('Time')
plt.legend(['accuracy', 'loss'])
plt.show()

# %%
def predict_image(image_path):
    img = image.load_img(image_path, target_size=(160,160,3))
    plt.imshow(img)
    plt.show()
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    images = np.vstack([x])
    pred = model.predict(images, batch_size=32)
    print("Actual: "+(image_path.split("/")[-1]).split("_")[0])
    print("Predicted: "+classes[np.argmax(pred)])

# %%
predict_image("../dataset/origin_images/Dilshod/face_11.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Actual: face
# Predicted: Brad Pitt
